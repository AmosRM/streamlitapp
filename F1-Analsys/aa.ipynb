# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

import fastf1 as ff
from fastf1 import plotting, utils

# %%
races = pd.read_html('https://en.wikipedia.org/wiki/2022_Formula_One_World_Championship')

# %%
races = races[1]

# %%
race = races['Grand Prix'].str.replace(' Grand Prix','').tolist()

# %%
year = range(2020,2023)
session = ['FP1', 'FP2', 'FP3', 'Q', 'SQ', 'R']

# %%
ss = ff.get_session(2021,'Silverston','R')
# ss.load()
# Out:
# api         WARNING
#
# NO CACHE! Api caching has not been enabled!
# 	It is highly recommended to enable this feature for much faster data loading!
# 	Use `fastf1.Cache.enable_cache('path/to/cache/')`

# %%
pd.unique(selected_race.laps['Driver'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-935726c19fa6> in <module>
# ----> 1 pd.unique(selected_race.laps['Driver'])
#
# NameError: name 'selected_race' is not defined

# %%
driver
# Out:
# ['SAI',
#  'VER',
#  'LEC',
#  'PER',
#  'HAM',
#  'NOR',
#  'ALO',
#  'RUS',
#  'ZHO',
#  'LAT',
#  'GAS',
#  'BOT',
#  'TSU',
#  'RIC',
#  'OCO',
#  'ALB',
#  'MAG',
#  'VET',
#  'MSC',
#  'STR']

# %%
drivers = races[5].iloc[2:23][1].tolist()
# Out:
# ['Max Verstappen',
#  'Charles Leclerc',
#  'Sergio Pérez',
#  'Carlos Sainz Jr.',
#  'George Russell',
#  'Lewis Hamilton',
#  'Lando Norris',
#  'Esteban Ocon',
#  'Valtteri Bottas',
#  'Fernando Alonso',
#  'Kevin Magnussen',
#  'Daniel Ricciardo',
#  'Pierre Gasly',
#  'Sebastian Vettel',
#  'Mick Schumacher',
#  'Yuki Tsunoda',
#  'Zhou Guanyu',
#  'Alexander Albon',
#  'Lance Stroll',
#  'Nicholas Latifi',
#  'Nico Hülkenberg']

# %%
selected_race = ff.get_session(2022,'Silverston','R').load_laps()
# Out:
# core           INFO 	Loading laps for British Grand Prix - Race [v2.1.13]
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api         WARNING 	Driver  1: Ignoring late data for a previously processed lap.The data may contain errors (previous: 39; current 40)
# api            INFO 	Fetching timing app data...
# core           INFO 	Processing timing data...
# api            INFO 	Fetching driver list...
# api            INFO 	Fetching session status data...
# api            INFO 	Fetching track status data...
# api            INFO 	Fetching weather data...
# core           INFO 	Loaded data for 20 drivers: ['55', '1', '16', '11', '44', '4', '14', '63', '24', '6', '10', '77', '22', '3', '31', '23', '20', '5', '47', '18']

# %%
selected_race
# Out:
#                       Time DriverNumber                LapTime  LapNumber  \
# 0   0 days 01:04:40.373000           55                    NaT        1.0
# 1   0 days 01:57:51.378000           55                    NaT        2.0
# 2   0 days 02:00:23.226000           55                    NaT        3.0
# 3   0 days 02:01:56.663000           55 0 days 00:01:33.437000        4.0
# 4   0 days 02:03:30.286000           55 0 days 00:01:33.623000        5.0
# ..                     ...          ...                    ...        ...
# 809 0 days 03:14:21.069000           18 0 days 00:01:33.196000       48.0
# 810 0 days 03:15:55.193000           18 0 days 00:01:34.124000       49.0
# 811 0 days 03:17:28.005000           18 0 days 00:01:32.812000       50.0
# 812 0 days 03:19:00.421000           18 0 days 00:01:32.416000       51.0
# 813 0 days 03:20:32.800000           18 0 days 00:01:32.379000       52.0
#
#      Stint             PitOutTime              PitInTime  \
# ...

# %%
selected_race.load_laps()
# Out:
# core           INFO 	Loading laps for British Grand Prix - Race [v2.1.13]
# api         WARNING
#
# NO CACHE! Api caching has not been enabled!
# 	It is highly recommended to enable this feature for much faster data loading!
# 	Use `fastf1.Cache.enable_cache('path/to/cache/')`
#
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api         WARNING 	Driver  1: Ignoring late data for a previously processed lap.The data may contain errors (previous: 39; current 40)
# api            INFO 	Fetching timing app data...
# core           INFO 	Processing timing data...
# api            INFO 	Fetching driver list...
# api            INFO 	Fetching session status data...
# api            INFO 	Fetching track status data...
# api            INFO 	Fetching weather data...
# core           INFO 	Loaded data for 20 drivers: ['55', '1', '16', '11', '44', '4', '14', '63', '24', '6', '10', '77', '22', '3', '31', '23', '20', '5', '47', '18']
# ...

# %%
selected_race.get_driver('SAI')

# %%
rtt = ff.get_session(2021,'Silverston','R')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-235-bb65670efed8> in <module>
#       1 rtt = ff.get_session(2021,'Silverston','R')
# ----> 2 rtt.load()
#
# AttributeError: 'Session' object has no attribute 'load'

# %%
rta = rtt.load_laps()
# Out:
# core           INFO 	Loading laps for British Grand Prix - Race [v2.1.13]
# api            INFO 	Fetching timing data...
# api            INFO 	Parsing timing data...
# api         WARNING 	Driver  4: Ignoring late data for a previously processed lap.The data may contain errors (previous: 43; current 44)
# api         WARNING 	Driver 55: Ignoring late data for a previously processed lap.The data may contain errors (previous: 7; current 8)
# api            INFO 	Fetching timing app data...
# core           INFO 	Processing timing data...
# api            INFO 	Fetching driver list...
# api            INFO 	Fetching session status data...
# api            INFO 	Fetching track status data...
# api            INFO 	Fetching weather data...
# core           INFO 	Loaded data for 20 drivers: ['33', '44', '77', '16', '4', '3', '14', '5', '31', '55', '10', '63', '7', '18', '99', '22', '6', '47', '9', '11']

# %%
a2 = rtt.load_telemetry()
# Out:
# api            INFO 	Fetching car data...
# api            INFO 	Parsing car data...
# api            INFO 	Fetching position data...
# api            INFO 	Parsing position data...
# api         WARNING 	Driver 241: Position data is incomplete!
# api         WARNING 	Driver 242: Position data is incomplete!
# api         WARNING 	Driver 243: Position data is incomplete!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
driver_fastest = rta.pick_driver('HAM').pick_fastest()
# Out:
# Time                  0 days 02:50:11.235000
# DriverNumber                              44
# LapTime               0 days 00:01:29.699000
# LapNumber                                 45
# Stint                                      3
# PitOutTime                               NaT
# PitInTime                                NaT
# Sector1Time           0 days 00:00:28.698000
# Sector2Time           0 days 00:00:36.382000
# Sector3Time           0 days 00:00:24.619000
# Sector1SessionTime    0 days 02:49:10.234000
# Sector2SessionTime    0 days 02:49:46.616000
# Sector3SessionTime    0 days 02:50:11.235000
# SpeedI1                                  NaN
# SpeedI2                                  264
# SpeedFL                                  253
# SpeedST                                  304
# Compound                                HARD
# TyreLife                                  18
# FreshTyre                               True
# LapStartTime          0 days 02:48:41.536000
# ...

# %%
a1 = driver_fastest.get_telemetry()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-232-882101e898f5> in <module>
# ----> 1 a1 = driver_fastest.get_telemetry()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastf1/core.py in get_telemetry(self)
#    2077             instance of :class:`Telemetry`
#    2078         """
# -> 2079         pos_data = self.get_pos_data(pad=1, pad_side='both')
#    2080         car_data = self.get_car_data(pad=1, pad_side='both')
#    2081
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fastf1/core.py in get_pos_data(self, **kwargs)
#    2119             instance of :class:`Telemetry`
#    2120         """
# -> 2121         pos_data = self.session.pos_data[self['DriverNumber']].slice_by_lap(self, **kwargs).reset_index(drop=True)
#    2122         return pos_data
#    2123
#
# KeyError: '44'
